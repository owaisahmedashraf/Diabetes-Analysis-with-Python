# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Lenovo T450\Documents\ATOMCAMP\Atomcamp python\diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#Question 1:

outcome_data = df["Outcome"].to_numpy()
unique_values = np.unique(outcome_data)
print(unique_values)
# Out:
# [0 1]

# %%
#Question 2:
Glucose_level = df["Glucose"].values
Glucose_level_mean = np.mean(Glucose_level)
print("The mean is:",Glucose_level_mean)
Glucose_level_STD = np.std(Glucose_level)
print("The Standard Deviation is:",Glucose_level_STD)
# Out:
# The mean is: 120.89453125
# The Standard Deviation is: 31.95179590820272

# %%
#Question 3:
BMI_data = df['BMI'].to_numpy()
BMI_data_median = np.median(BMI_data)
print("The median is: ",BMI_data_median)
# Out:
# The median is:  32.0

# %%
#Question 4:
pregnancies_data = df["Pregnancies"].to_numpy()
unique_preg, count =np.unique(pregnancies_data,return_counts = True)

for i in range(len(unique_preg)):
    print(f"Count of patients with {unique_preg[i]} pregnanices are {count[i]}")
# Out:
# Count of patients with 0 pregnanices are 111
# Count of patients with 1 pregnanices are 135
# Count of patients with 2 pregnanices are 103
# Count of patients with 3 pregnanices are 75
# Count of patients with 4 pregnanices are 68
# Count of patients with 5 pregnanices are 57
# Count of patients with 6 pregnanices are 50
# Count of patients with 7 pregnanices are 45
# Count of patients with 8 pregnanices are 38
# Count of patients with 9 pregnanices are 28
# Count of patients with 10 pregnanices are 24
# Count of patients with 11 pregnanices are 11
# Count of patients with 12 pregnanices are 9
# Count of patients with 13 pregnanices are 10
# Count of patients with 14 pregnanices are 2
# Count of patients with 15 pregnanices are 1
# Count of patients with 17 pregnanices are 1

# %%
#Question 5:
insulin_level = df["Insulin"].values
max_insulin_level = np.max(insulin_level)
min_insulin_level = np.min(insulin_level)
print("max:",max_insulin_level,"min:",min_insulin_level)
# Out:
# max: 846 min: 0

# %%
#Question 6:
age_data = df["Age"].values
print("variance:",np.var(age_data))
# Out:
# variance: 138.12296379937067

# %%
#Question 7:
Glucose_level = df["Glucose"].values
Glucose_level[Glucose_level > np.mean(Glucose_level)]
# Out:
# array([148, 183, 137, 197, 125, 168, 139, 189, 166, 126, 196, 143, 125,
#        147, 145, 158, 122, 138, 180, 133, 171, 159, 180, 146, 176, 150,
#        187, 146, 133, 141, 146, 139, 126, 129, 131, 137, 136, 123, 134,
#        142, 144, 122, 163, 151, 125, 126, 144, 171, 155, 160, 146, 124,
#        162, 132, 173, 122, 170, 125, 129, 128, 154, 147, 136, 156, 153,
#        188, 152, 163, 151, 131, 148, 134, 179, 129, 143, 130, 141, 194,
#        181, 128, 139, 123, 159, 135, 158, 148, 138, 196, 162, 184, 147,
#        179, 140, 151, 125, 177, 158, 142, 162, 197, 142, 134, 122, 171,
#        181, 179, 164, 139, 146, 184, 122, 165, 124, 129, 193, 155, 191,
#        141, 142, 123, 138, 128, 146, 122, 146, 129, 133, 161, 136, 155,
#        128, 128, 161, 151, 146, 126, 167, 144, 150, 161, 137, 128, 124,
#        155, 182, 194, 129, 124, 152, 157, 122, 179, 180, 165, 152, 178,
#        130, 122, 126, 139, 137, 165, 125, 129, 196, 189, 158, 146, 147,
# ...

# %%
#Question8:

new_list=[]
def norm_bp(column_name):
    a = df[column_name].to_numpy()
    b = np.mean(a)
    c = np.std(a)
    for i in a:
        norm = ((i - b)/c)
        new_list.append(norm)
    return(new_list)

# %%
p = norm_bp('BloodPressure')
np.array(p).shape
# Out:
# (768,)

# %%
#question 9

diabetes_ped_data = df['DiabetesPedigreeFunction'].to_numpy()
percentile_25 = np.percentile(diabetes_ped_data,25)
print("The 25th percentile is:",percentile_25)
# Out:
# The 25th percentile is: 0.24375

# %% [markdown]
# # Pandas Questions

# %%
# Question 1:

df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
#question 2:
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#question 3:
#pd.options.display.max_rows = 9999
df['Insulin'].value_counts()
# Out:
# Insulin
# 0      374
# 105     11
# 130      9
# 140      9
# 120      8
#       ...
# 73       1
# 171      1
# 255      1
# 52       1
# 112      1
# Name: count, Length: 186, dtype: int64

# %%
#another way to do question 3 is:
zeros= (df['Insulin']==0).sum()
print(zeros)
# Out:
# 374

# %%
#Question 4:

def weight_class(bmi_value):
        if bmi_value < 18.5:
            return("Underweight")
        elif 18.5 <= bmi_value <= 24.9:
            return("Normal")
        elif 25 <= bmi_value <= 29.9:
            return("Overweight")
        else:
            return("Obese")

# %%
df['BMI_Class'] = df['BMI'].apply(weight_class)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome   BMI_Class
# 0                       0.627   50        1       Obese
# ...

# %%
#try doing it another way using concat which you thought of on another sheet

# %%
#Question 5:
avg_age_outcome = df.groupby('Outcome')['Age'].mean()
avg_age_outcome
# Out:
# Outcome
# 0    31.190000
# 1    37.067164
# Name: Age, dtype: float64

# %%
#Question 6:
filtered_patients = df[df['Glucose']>120]
filtered_patients
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome    BMI_Class
# 0                       0.627   50        1        Obese
# ...

# %%
filtered_rows= df.query('Age > 30 and BMI <30')
filtered_rows
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 9              8      125             96              0        0   0.0
# 12            10      139             80              0        0  27.1
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 722            1      149             68             29      127  29.3
# 730            3      130             78             23       79  28.4
# 734            2      105             75              0        0  23.3
# 749            6      162             62              0        0  24.3
# 762            9       89             62              0        0  22.5
#
#      DiabetesPedigreeFunction  Age  Outcome    BMI_Class
# 1                       0.351   31        0   Overweight
# ...

# %%
#Question #8:
#pd.options.display.max_rows = 9999
df.query('Glucose != 0 and BloodPressure != 0 and BMI != 0',inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome   BMI_Class
# 0                       0.627   50        1       Obese
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 724 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               724 non-null    int64
#  1   Glucose                   724 non-null    int64
#  2   BloodPressure             724 non-null    int64
#  3   SkinThickness             724 non-null    int64
#  4   Insulin                   724 non-null    int64
#  5   BMI                       724 non-null    float64
#  6   DiabetesPedigreeFunction  724 non-null    float64
#  7   Age                       724 non-null    int64
#  8   Outcome                   724 non-null    int64
#  9   BMI_Class                 724 non-null    object
# dtypes: float64(2), int64(7), object(1)
# memory usage: 62.2+ KB

# %%
#Question 9:
df.reset_index(drop=True,inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 719           10      101             76             48      180  32.9
# 720            2      122             70             27        0  36.8
# 721            5      121             72             23      112  26.2
# 722            1      126             60              0        0  30.1
# 723            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome   BMI_Class
# 0                       0.627   50        1       Obese
# ...

# %%
#Question 10:

subset = df[["Age","Glucose","Outcome"]]
subset.to_csv('Assignment_3.csv')

# %% [markdown]
# # Matplotlib Questions

# %%
#Question 1
age_values=df['Age'].to_numpy()

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax.hist(age_values,bins=100,color='red')
ax.set_title('Histogram of Age')
ax.set_xlabel('Age')
ax.set_ylabel('Frequency')
plt.show()

# %%
plt.hist(age_values,bins=50,color='red')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.show()

# %%
#Question 2:
glucose_levels=df['Glucose'].to_numpy()
insulin_levels=df['Insulin'].to_numpy()
plt.scatter(glucose_levels,insulin_levels)
plt.xlabel("Glucose Levels")
plt.ylabel("Insulin Levels")
plt.title("Scatter plot of glucose vs insulin levels")
plt.show()

# %%
#Question 3:
bmi_oc_grp = df.groupby('Outcome')['BMI'].mean()
bmi_oc_grp
# Out:
# Outcome
# 0    30.974947
# 1    35.313655
# Name: BMI, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(6,4))
p=ax.bar(bmi_oc_grp.index,bmi_oc_grp.values,width=0.1,edgecolor='black',color='red')
ax.set_xlabel('Outcomes')
ax.set_ylabel('BMI')
ax.bar_label(p)
ax.set_title('Bar chart of mean BMI vs outcome')
plt.show()

# %%
#Question 4:
age_sorted_data = df.sort_values(by='Age')
age_sorted_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 97             1      126             56             29      152  28.7
# 399            2      115             64             22        0  30.8
# 411            1       97             70             15        0  18.2
# 111            4       99             76             15       51  23.2
# 437            0      124             56             13      105  21.8
# ..           ...      ...            ...            ...      ...   ...
# 459            8      194             80              0        0  26.1
# 634            8       91             82              0        0  35.6
# 115            5      132             80              0        0  26.8
# 626            4      145             82             18        0  32.5
# 431            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome    BMI_Class
# 97                      0.801   21        0   Overweight
# ...

# %%
plt.plot(age_sorted_data['Age'],age_sorted_data['BloodPressure'],linestyle='-',color='m')
plt.title('Blood Pressure by Age')
plt.xlabel('Age')
plt.ylabel('Blood Pressure')
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax.plot(age_sorted_data['Age'],age_sorted_data['BloodPressure'],linestyle='--',color='red')
ax.set_xlabel('Age')
ax.set_ylabel('Blood Pressure')
ax.set_title('Blood Pressure by Age')
plt.grid(True)
plt.show()

# %%
#Question 5:
BMI_group = df.groupby('Outcome')['BMI'].apply(list)
BMI_group
# Out:
# Outcome
# 0    [26.6, 28.1, 25.6, 37.6, 27.1, 43.3, 39.3, 35....
# 1    [33.6, 23.3, 43.1, 31.0, 30.5, 38.0, 30.1, 25....
# Name: BMI, dtype: object

# %%
plt.boxplot(BMI_group, labels=BMI_group.index)
plt.title('Box plot of BMI by outcome')
plt.xlabel('Outcome')
plt.ylabel('BMI')
plt.show()

# %%
sns.catplot(data=df,kind='box',x='Outcome',y='BMI')
sns.set_palette('deep')
sns.set_style('whitegrid')
plt.title('Box plot of BMI by outcome')
plt.show()

# %%
#Question 6:
diabetes_outcome=df.groupby('Outcome').size()
diabetes_outcome
# Out:
# Outcome
# 0    475
# 1    249
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.pie(diabetes_outcome,labels=diabetes_outcome.index,autopct='%1.2f%%')
ax.set_title('Pie chart of diabetes outcomes')
plt.show()

# %%
#Question 7:

preg_outcome_grouped=df.groupby(['Pregnancies','Outcome']).size().unstack()
preg_outcome_grouped
# Out:
# Outcome          0     1
# Pregnancies
# 0             67.0  32.0
# 1            103.0  28.0
# 2             78.0  18.0
# 3             46.0  26.0
# 4             44.0  21.0
# 5             35.0  20.0
# 6             31.0  15.0
# 7             18.0  24.0
# 8             16.0  20.0
# 9             10.0  18.0
# 10            13.0   9.0
# 11             4.0   6.0
# 12             5.0   4.0
# 13             5.0   4.0
# 14             NaN   2.0
# 15             NaN   1.0
# 17             NaN   1.0

# %%
preg_outcome_grouped.plot(kind='bar', stacked=True, figsize=(8, 6), colormap='inferno')
plt.ylabel('Outcome')
plt.xlabel('Number of Pregnancies')
plt.title('Stacked Bar Chart of Pregnancies by Outcome')
plt.show()

# %%
#Question 8:
glucose_values=df['Glucose'].to_numpy()
blood_pressure_values=df['BloodPressure'].values

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

axs[0].hist(glucose_values,bins=30,color='red')
axs[0].set_xlabel('Glucose Values')
axs[0].set_ylabel('Frequency')
axs[0].set_title('Histogram of Glucose')

axs[1].hist(blood_pressure_values,bins=30,color='green')
axs[1].set_xlabel('Blood Pressure Values')
axs[1].set_ylabel('Frequency')
axs[1].set_title('Histogram of Blood Pressure')

plt.tight_layout()
plt.show()

# %%
#Question 9:

corr_data = df.corr(numeric_only=True)
corr_data
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.134915       0.209668      -0.095683
# Glucose                      0.134915  1.000000       0.223331       0.074381
# BloodPressure                0.209668  0.223331       1.000000       0.011777
# SkinThickness               -0.095683  0.074381       0.011777       1.000000
# Insulin                     -0.080059  0.337896      -0.046856       0.420874
# BMI                          0.012342  0.223276       0.287403       0.401528
# DiabetesPedigreeFunction    -0.025996  0.136630      -0.000075       0.176253
# Age                          0.557066  0.263560       0.324897      -0.128908
# Outcome                      0.224417  0.488384       0.166703       0.092030
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.080059  0.012342                 -0.025996
# ...

# %%
# I dont why it doesnt show all the values it works fine on colab but not here, I have tried using 2 different libraries and it doesnt work
sns.heatmap(corr_data, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation between Numeric Features')
plt.show()

# %%
#I tried doing it using matplotlib but I cant figure out a way to show values in the boxes
fig,ax=plt.subplots(figsize=(8,6))
p=ax.imshow(corr_data,cmap='coolwarm',interpolation = 'nearest')
plt.colorbar(p)
plt.title('Correlation between numeric features')
plt.tight_layout()
plt.show()
